# %% [markdown]
# ### (참고) jupyter lab 바탕화면 실행버튼 만들기

# %% [markdown]
# https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=worb1605&logNo=221456891149
# https://yunwoong.tistory.com/78

# %% [markdown]
# # 섹션1. 개발 환경 세팅

# %% [markdown]
# ## 1.4 간단한 시스템 명령어

# %% [markdown]
# mkdir + 폴더명 : 폴더명 폴더 생성
# ![image.png](attachment:806ab534-bfc8-4b6b-bf5a-649ca947c9d6.png)

# %% [markdown]
# start + .(dot) : 현재 위치 폴더 열기

# %% [markdown]
# ## 1.5 jupyter 실행하기

# %% [markdown]
# Anaconda Prompt에서 cmd 명령어를 이용하여 Jupyter lab 실행하기

# %% [markdown]
# ## 1.6 jupyter 둘러보기

# %% [markdown]
# 현재경로 확인: pwd

# %%
pwd
# Out:
# 'C:\\Users\\smile\\OneDrive\\coding\\python\\study\\(inflearn)DeepingSauce\\python for everyone'

# %% [markdown]
# pr을 누르고 tab을 누르면 pr로 시작하는 명령어들의 힌트를 볼 수 있다

# %% [markdown]
# ![image.png](attachment:e92624f7-d224-40c1-8339-585c86e9abda.png)

# %% [markdown]
# print를 누르고 shift+tab을 누르면 해당 명령어의 기능에 대한 설명을 볼 수 있다

# %% [markdown]
# ![image.png](attachment:eb2d6302-8581-4ea6-95f4-a31c9e139106.png)
